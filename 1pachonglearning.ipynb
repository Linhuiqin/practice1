# %%
'''通常编写爬虫代码，使用如下三行代码（两种方法）就可以实现一个网页的基本访问'''
'''
from urllib import request
rsp=request.urlopen(url='某某网站')
print(rsp.read().decode('编码'))
#或者
import requests
rsp=requests.get(url='某某网站')
print(rsp.text)
'''
'''获取网页没报错，但是输出信息没有在浏览器上看到的那么多，这有可能是网页使用了动态加载的原因
一般用爬虫爬取到的数据是当前网页已经完全加载的，而动态网页使用了ajax技术，因此用爬虫无法爬取到那部分数据
1直接找到这个ajax的相关网页链接，访问这个链接，从而得到相关数据
2直接使用selenium这个模块，操作浏览器访问
如果读者使用第1种解决方式，有可能你访问的那个链接一些参数是加密的，这时你需要利用js断点（使用谷歌浏览器），
找到那段加密参数加密之前的数据信息和相关的一些js加密函数，找到加密之前的数据信息的组合规则。关于js加密函数，
如果简单的话，直接用Python模拟出加密效果即可；如果复杂的话，最好使用execjs或者其他Python模块下的一些方法
去执行这些js加密函数。'''
#type(rsp)可查看rsp类型，为response类型
#r.headers可查看通过get请求获得页面的同步信息
#response对象属性-r.status_code，r.text，
#r.encoding，从http header中猜测的响应内容编码方式（如果header中不存在charset字段，则认为编码为
#ISO-8859-1，但这样的编码并不能解析中文，因此get获取到的网页内容看不到中文会是乱码）
#r.apparent_encoding,从内容中分析出的响应内容编码方式（备选编码方式）
#r.content
#图片资源都是以二进制形式存储的
#获取网上资源有这么个流程，先判断状态码，如果是200，再用response属性方法来解析返回的内容
#如果用encoding不能正确解码返回内容时，那就要用apparent encoding来解析。

'''
网络连接有风险，异常处理很重要
requests库的异常有
requests.ConnectionError网络连接错误异常，如dns查询失败，拒绝连接等
requests.httperrorhttp错误异常（http协议层面出现的错误）
requests.urlrequiredURL缺失异常
requests.toomanyredirects超过最大重定向次数，产生重定向异常（对复杂链接访问时经常会遇到的错误）
requests.connectimeout连接远程服务器超时异常
requests.timeout请求URL超时，产生超时异常
理解response类非常重要，因为这个对象返回了所有的网页内容，r.raise_for_status这个方法是专门和异常打交道
的方法，自动识别状态码，如果不是200会产生httperror异常
通用代码框架最大的作用，使得用户访问或者爬取网页变得更有效，稳定，可靠

http协议
想要获取信息，用get，head。想要对网页信息进行操作，及把自己的信息传到网页上，用put,post,pactch,delete
网络通道和服务器都是黑盒子，能看到的只有URL链接及对URL的相关操作
http协议的方法与requests库的方法功能是一致的'''
# Out:
# '通常编写爬虫代码，使用如下三行代码（两种方法）就可以实现一个网页的基本访问'
# "\nfrom urllib import request\nrsp=request.urlopen(url='某某网站')\nprint(rsp.read().decode('编码'))\n#或者\nimport requests\nrsp=requests.get(url='某某网站')\nprint(rsp.text)\n"
# '获取网页没报错，但是输出信息没有在浏览器上看到的那么多，这有可能是网页使用了动态加载的原因\n一般用爬虫爬取到的数据是当前网页已经完全加载的，而动态网页使用了ajax技术，因此用爬虫无法爬取到那部分数据\n1直接找到这个ajax的相关网页链接，访问这个链接，从而得到相关数据\n2直接使用selenium这个模块，操作浏览器访问\n如果读者使用第1种解决方式，有可能你访问的那个链接一些参数是加密的，这时你需要利用js断点（使用谷歌浏览器），\n找到那段加密参数加密之前的数据信息和相关的一些js加密函数，找到加密之前的数据信息的组合规则。关于js加密函数，\n如果简单的话，直接用Python模拟出加密效果即可；如果复杂的话，最好使用execjs或者其他Python模块下的一些方法\n去执行这些js加密函数。'

# %%
'''requests库学习
一共只有7个对外使用的方法，由于网络安全的限制，我们很难向一个URL去post，put,patch,delete
重点掌握get，head
只需要掌握爬去网页的通用代码框架，一定要用try except的方式来保证连接所可能发生的异常能被有效处理
'''
#reqursts库的request方法，是所有方法的基础方法
 #params可以把一些键值对增加到URL中
 #data
 #json
 #headers
 #cookies和auth字段是高级字段对应高级功能
 #files向某个链接提交某个文件
 #   
 #proxies，字典类型，设定访问代理服务器，可以增加登陆认证
 pxs={'http':'http://user:pass@10.10.10.1:1234'#这个是http访问时使用的代理，在代理中可以增加用户名和密码的设置
      'https':'https://10.10.10.1:4321'}#这个是https的代理服务器
 r=requests.request('GET','http://www.baidu.com',proxies=pxs)
 #这样在访问百度时的IP地址，就是代理服务器的IP地址。可以隐藏用户在爬取网址时用户原IP地址，防止爬虫逆追踪
 
 #allow_redirects:Ture/False，默认为Ture，重定向开关
 #stream
 #vertify

#requests库的get方法，最常用。向某个服务器去提交一些资源的功能是严格受控的，因为这里有很大的安全问题

#requests库的head方法
import requests
r=requests.head('http://httpbin.org/get')
print(r.headers)
print(r.text)#用head请求，显示文本为空。可以用很少的流量，获取网页概要信息

#requests库的post方法，可以用post方法向服务器提交新增数据
payload={'key1':'value1','key2':'value2'}#字典
r=requests.post('http://httpbin.org/post',data=payload)
print(r.text)#如果用post新增内容，内容为字典，则该字典会默认被存储在表单的字段下
r2=requests.post('http://httpbin.org/post',data='xiaoyu')
print(r2.text)#如果用post新增内容，内容为字符串，则该字符串会被自动编码为data字段下

#requests库的put方法，直接将原有数据覆盖掉


'''用Request类来构建请求，比较强大，可设置了 data、headers 和 method
class urllib.request.Request(url, data=None, headers={},
origin_req_host=None, unverifiable=False, method=None)
参数headers是一个字典，添加请求头最常用的方法就是通过修改User-Agent来伪装浏览器，
默认的 User-Agent 是 Python-urllib，我们可以通过修改它来伪装浏览器。
比如要伪装火狐浏览器，你可以把它设置为：
Mozilla/5.0 (X11; U; Linux i686) Gecko/20071127 Firefox/2.0.0.11
第四个参数 origin_req_host 指的是请求方的 host 名称或者 IP 地址。
第五个参数 unverifiable 表示这个请求是否是无法验证的，默认是 False，
意思就是说用户没有足够权限来选择接收这个请求的结果。
例如，我们请求一个 HTML 文档中的图片，但是我们没有自动抓取图像的权限，
这时 unverifiable 的值就是 True。
第六个参数 method 是一个字符串，用来指示请求使用的方法，比如 GET、POST 和 PUT 等
'''

'''扩充关于request的知识
1在Python中，我们可以使用requests库来获取网页内容。requests库默认使用UTF-8编码，
但是很多网站的编码方式可能是GBK、GB2312等，因此需要我们手动指定编码方式'''
# Out:
# 'requests库学习\n'
# {'Date': 'Fri, 25 Aug 2023 02:13:18 GMT', 'Content-Type': 'application/json', 'Content-Length': '310', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
#
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.1",
#     "X-Amzn-Trace-Id": "Root=1-64e80e3e-30b98d9c531475a367a74362"
#   },
#   "json": null,
#   "origin": "140.240.6.224",
#   "url": "http://httpbin.org/post"
# }
#
# {
#   "args": {},
#   "data": "xiaoyu",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "6",
# ...

# %%
'''本行代码讲解利用urlopen方法实现基本网页请求，只能完成较为简单的请求'''

'''python2中有有 urllib 和 urllib2 两个库
而Python3中统一为 urllib，
其官方文档链接为：https://docs.python.org/3/library/urllib.html
包含如下 4 个模块。
request：它是最基本的 HTTP 请求模块，可以用来模拟发送请求。
就像在浏览器里输入网址然后回车一样，只需要给库方法传入URL以及额外的参数，
就可以模拟实现这个过程了。
error：异常处理模块，如果出现请求错误，我们可以捕获这些异常，
然后进行重试或其他操作以保证程序不会意外终止。
parse：一个工具模块，提供了许多 URL 处理方法，比如拆分、解析和合并等。
robotparser：主要用来识别网站的 robots.txt 文件，
然后判断哪些网站可以爬，哪些网站不可以爬，它其实用得比较少'''
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import urllib.request

#示例 只用两行代码便完成python官网的抓取
#response = urllib.request.urlopen('https://www.python.org')#代码太长
response.read().decode('utf-8')
type(response)#返回的是HTTPResposne类型的对象

'''HTTPResposne类型的对象可以使用的方法及属性'''

'''request模块中urlopen方法讲解
urllib.request.urlopen(url[, data=None, [timeout,]*, cafile=None, 
                       capath=None, cadefault=False, context=None])
'''
#data参数的使用，通过设置 timeout 这个参数来实现超时处理，有时还是很有用的
#data = bytes(urllib.parse.urlencode({'name': 'xiaoyu'}), encoding='utf-8')
#这里传递参数name，值为xiaoyu。它需要被转码为字节流类型bytes，
#用到bytes方法，该方法第一个参数需要字符串类型str，第二个参数指定编码格式，指定为utf-8
#参数字典转化为字符串需要用urllib.parse模块里的urlencode方法
response = urllib.request.urlopen('https://httpbin.org/post', data=data)
#httpbin.org这个站点可以提供http请求测试，httpbin.org/post这个站点可以用来测试post请求
print(response.read().decode('utf-8'))
#以上传递的参数出现在form字段中，这表明模拟了表单提交的方式，以post方式传输数据
# Out:
# '本行代码讲解利用urlopen方法实现基本网页请求，只能完成较为简单的请求'
# 'python2中有有 urllib 和 urllib2 两个库\n而Python3中统一为 urllib，\n其官方文档链接为：https://docs.python.org/3/library/urllib.html\n包含如下 4 个模块。\nrequest：它是最基本的 HTTP 请求模块，可以用来模拟发送请求。\n就像在浏览器里输入网址然后回车一样，只需要给库方法传入URL以及额外的参数，\n就可以模拟实现这个过程了。\nerror：异常处理模块，如果出现请求错误，我们可以捕获这些异常，\n然后进行重试或其他操作以保证程序不会意外终止。\nparse：一个工具模块，提供了许多 URL 处理方法，比如拆分、解析和合并等。\nrobotparser：主要用来识别网站的 robots.txt 文件，\n然后判断哪些网站可以爬，哪些网站不可以爬，它其实用得比较少'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 21
#      17 import urllib.request
#      19 #示例 只用两行代码便完成python官网的抓取
#      20 #response = urllib.request.urlopen('https://www.python.org')#代码太长
# ---> 21 response.read().decode('utf-8')
#      22 type(response)#返回的是HTTPResposne类型的对象
#      24 '''HTTPResposne类型的对象可以使用的方法及属性'''
#
# NameError: name 'response' is not defined

# %%
'''url指网页链接，开头的http或https指的是访问资源需要的协议类型
HTTP的全称是Hyper Text Transfer Protocol超文本传输协议
HTTP协议是用于从网络传输超文本数据到本地浏览器的传送协议，
它能保证高效而准确地传送超文本文档。e )
HTTPS是Hyper Text Transfer Protocol over Secure Socket Layer
是HTTP的安全版，即HTTP下加入SSL层，简称为HTTPS。

hypertext超文本-即网页源代码（一系列html代码），浏览器会解析这些超文本形成我们平时看到的网页页面

HTML定义了网页的内容和结构，CSS描述了网页的样式，JavaScript定义了网页的行为
源代码html根元素-元素<head>(-属性charset，元素<meta>，元素<title>)
              -元素<body>(-属性href，元素<a>，元素<h1>)'''
# Out:
# 'url指网页链接，开头的http或https指的是访问资源需要的协议类型\nHTTP的全称是Hyper Text Transfer Protocol超文本传输协议\nHTTP协议是用于从网络传输超文本数据到本地浏览器的传送协议，\n它能保证高效而准确地传送超文本文档。e )\nHTTPS是Hyper Text Transfer Protocol over Secure Socket Layer\n是HTTP的安全版，即HTTP下加入SSL层，简称为HTTPS。\n\nhypertext超文本-即网页源代码（一系列html代码），浏览器会解析这些超文本形成我们平时看到的网页页面\n\nHTML定义了网页的内容和结构，CSS描述了网页的样式，JavaScript定义了网页的行为\n源代码html根元素-元素<head>(-属性charset，元素<meta>，元素<title>)\n              -元素<body>(-属性href，元素<a>，元素<h1>)'

# %%
'''如果在构造请求过程中，想同时进行Cookies 处理、代理设置
则需要用到Handler，利用它们，我们几乎可以做到 HTTP 请求中所有的事情

urllib.request 模块里的 BaseHandler 类，它是所有其他 Handler 的父类，
它提供了最基本的方法，例如 default_open、protocol_request 等
继承了BaseHandler的子类有
HTTPDefaultErrorHandler 用于处理 HTTP 响应错误，错误都会抛出 HTTPError 类型的异常。
HTTPRedirectHandler 用于处理重定向。
HTTPCookieProcessor 用于处理 Cookies。
ProxyHandler 用于设置代理，默认代理为空。
HTTPPasswordMgr 用于管理密码，它维护了用户名和密码的表。
HTTPBasicAuthHandler 用于管理认证，如果一个链接打开时需要认证，那么可以用它来解决认证问题
https://docs.python.org/3/library/urllib.request.html#urllib.request.BaseHandler'''

#子类HTTPBasicAuthHandler，用于需要先登陆账号密码才能访问的网页
from urllib.request import HTTPPasswordMgrWithDefaultRealm, HTTPBasicAuthHandler, build_opener
from urllib.error import URLError

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
#pyhon升级到2.7.9以后，引入了一个新特性，当使用urllib打开https的链接时，会检验一次ssl证书。
#而当目标网站使用的是自签名证书时，就会抛出urllib.URLError的错误
#全局取消证书的验证，简易方便，但对整个项目会出现安全性的相关问题

username = 'admin'
password = 'admin'
url = 'https://ssr3.scrape.center/'

p = HTTPPasswordMgrWithDefaultRealm()
p.add_password(None, url, username, password)
auth_handler = HTTPBasicAuthHandler(p)
opener = build_opener(auth_handler)

try:
    result = opener.open(url)
    html = result.read().decode('utf-8')
    print(html)
except URLError as e:
    print(e.reason)

#代理 做爬虫的时候，免不了要使用代理，以下演示如何添加代理
from urllib.error import URLError
from urllib.request import ProxyHandler, build_opener

proxy_handler = ProxyHandler({
    'http': 'http://127.0.0.1:8080',
    'https': 'https://127.0.0.1:8080'
})
opener = build_opener(proxy_handler)
try:
    response = opener.open('https://www.baidu.com')
    print(response.read().decode('utf-8'))
except URLError as e:
    print(e.reason)
# Out:
# <html lang="en">
# <head>
#
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width,initial-scale=1">
#   <link rel="icon" href="/static/img/favicon.ico">
#   <title>Scrape | Movie</title>
#
#
#   <link href="/static/css/app.css" type="text/css" rel="stylesheet">
#
# <link href="/static/css/index.css" type="text/css" rel="stylesheet">
#
# </head>
# <body>
# <div id="app">
#   <div data-v-74e8b908="" class="el-row" id="header">
#     <div data-v-74e8b908="" class="container el-col el-col-18 el-col-offset-3">
#       <div data-v-74e8b908="" class="el-row">
#         <div data-v-74e8b908="" class="logo el-col el-col-4">
#           <a data-v-74e8b908="" href="/" class="router-link-exact-active router-link-active">
#             <img data-v-74e8b908="" src="/static/img/logo.png" class="logo-image">
#             <span data-v-74e8b908="" class="logo-title">Scrape</span>
#           </a>
#         </div>
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import requests,re

#url='https://www.sohu.com/a/633768332_120099885'
#res=requests.get(url)
#res.text
#title = re.findall('<p>(.*?)</p>',res.text)
#证实了我的想法，匹配<p>   </p>格式中的所有内容
#title


'''爬取豆瓣电影排名250
418指有反爬虫机制，解决方法就是带请求头header(suser-agent)访问
需要设置其header属性，为user-agent
但后面这个Mozilla/5.0意思是把请求头设置为火狐浏览器'''
url_douban='https://movie.douban.com/top250'
res_douban=requests.get(url_douban)
'''418报错'''
res_douban

#设置请求头属性即可消除反爬虫障碍
res_douban1=requests.get(url_douban,headers={'user-agent':'Mozilla/5.0'})
#res_douban1.text
title_douban1=re.findall('<span class="title">(.*?)</span>',res_douban1.text)
title_douban1

url_scrape='https://ssr1.scrape.center'
res_scrape=requests.get(url_douban)
res_scrape
# Out:
# '爬取豆瓣电影排名250\n418指有反爬虫机制，解决方法就是带请求头header(suser-agent)访问\n需要设置其header属性，为user-agent'
# '418报错'
# <Response [418]>
# ['肖申克的救赎',
#  '&nbsp;/&nbsp;The Shawshank Redemption',
#  '霸王别姬',
#  '阿甘正传',
#  '&nbsp;/&nbsp;Forrest Gump',
#  '泰坦尼克号',
#  '&nbsp;/&nbsp;Titanic',
#  '这个杀手不太冷',
#  '&nbsp;/&nbsp;Léon',
#  '美丽人生',
#  '&nbsp;/&nbsp;La vita è bella',
#  '千与千寻',
#  '&nbsp;/&nbsp;千と千尋の神隠し',
#  '辛德勒的名单',
#  '&nbsp;/&nbsp;Schindler&#39;s List',
#  '盗梦空间',
#  '&nbsp;/&nbsp;Inception',
#  '星际穿越',
#  '&nbsp;/&nbsp;Interstellar',
#  '楚门的世界',
#  '&nbsp;/&nbsp;The Truman Show',
#  '忠犬八公的故事',
#  '&nbsp;/&nbsp;Hachi: A Dog&#39;s Tale',
#  '海上钢琴师',
#  '&nbsp;/&nbsp;La leggenda del pianista sull&#39;oceano',
#  '三傻大闹宝莱坞',
#  '&nbsp;/&nbsp;3 Idiots',
#  '放牛班的春天',
#  '&nbsp;/&nbsp;Les choristes',
#  '机器人总动员',
#  '&nbsp;/&nbsp;WALL·E',
#  '无间道',
#  '&nbsp;/&nbsp;無間道',
#  '疯狂动物城',
#  '&nbsp;/&nbsp;Zootopia',
#  '控方证人',
#  '&nbsp;/&nbsp;Witness for the Prosecution',
#  '大话西游之大圣娶亲',
# ...

# %%
'''异常的作用之一
比如不希望爬虫过程中因为某个网页加载太久而抛出异常，
那就可以预先设定好，如果遇到该异常，直接跳过该网页的抓取
就可以避免在网页抓取过程中由于某个网页加载过久而中断抓取程序'''

import socket
import urllib.request
import urllib.error

try:
    response = urllib.request.urlopen('https://httpbin.org/get', timeout=0.1)
except urllib.error.URLError as e:
    if isinstance(e.reason, socket.timeout):
        print('TIME OUT')
# Out:
# TIME OUT

# %%
'''京东商品页面爬取练习'''
import requests
r=requests.get("https://item.jd.com/2967929.html")
print(r.status_code)#检查状态码是否为200
print(r.encoding)#再看一下网页编码
#返回gbk或者utf-8，说明我们从http的头部就可以解析出这个页面的编码信息，这说明京东网站提供了这个
#页面信息的相关编码，接下来可以看一下返回的内容对不对
print(r.text[:1000])

#爬取失败☹️
# Out:
# '京东商品页面爬取练习'
# 200
# utf-8
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset="utf8" version='1'/>
#     <title>京东(JD.COM)-正品低价、品质保障、配送及时、轻松购物！</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=yes"/>
#     <meta name="description"
#           content="京东JD.COM-专业的综合网上购物商城，为您提供正品低价的购物选择、优质便捷的服务体验。商品来自全球数十万品牌商家，囊括家电、手机、电脑、服装、居家、母婴、美妆、个护、食品、生鲜等丰富品类，满足各种购物需求。"/>
#     <meta name="Keywords" content="网上购物,网上商城,家电,手机,电脑,服装,居家,母婴,美妆,个护,食品,生鲜,京东"/>
#     <script type="text/javascript">
#         window.point = {}
#         window.point.start = new Date().getTime()
#     </script>
#     <link rel="dns-prefetch" href="//static.360buyimg.com"/>
#     <link rel="dns-prefetch" href="//misc.360buyimg.com"/>
#     <link rel="dns-prefetch" href="//img10.360buyimg.com"/>
#     <link rel="dns-prefetch" href="//img11.360buyimg.com"/>
#     <link rel="dns-prefetch" href="//img12.360buyimg.com"/>
# ...

# %%
'''亚马逊商品页面爬取练习'''
#Mozilla/5.0为标准的浏览器身份标识字段
import requests
#r=requests.get('https://origin-www.amazon.cn/dp/B0758HXCS3/ref=s9_acsd_ri_bw_c2_x_2_i?pf_rd_m=A1U5RCOVU0NYF2&pf_rd_s=merchandised-search-10&pf_rd_r=7XT6HH5ZKQGWYKR53VNA&pf_rd_t=101&pf_rd_p=e724078e-46ef-4e1a-88bb-347788648990&pf_rd_i=2336219071&th=1')
url='https://origin-www.amazon.cn/dp/B0758HXCS3/ref=nav_signin?pf_rd_m=A1U5RCOVU0NYF2&pf_rd_s=merchandised-search-10&pf_rd_r=7XT6HH5ZKQGWYKR53VNA&pf_rd_t=101&pf_rd_p=e724078e-46ef-4e1a-88bb-347788648990&pf_rd_i=2336219071&th=1'
r=requests.get(url,headers={'user-agent':'Mozilla/5.0'})
print(r.status_code)
print(r.encoding)
print(r.apparent_encoding)
r.encoding=r.apparent_encoding
print(r.encoding)
print(r.status_code)
print(r.request.headers)#查看访问的服务器名称是什么，python，因此503状态码表示网站识别为爬虫
print(r.text[2000:3000])

#爬取页面失败，需要传入cookie信息
# Out:
# '亚马逊商品页面爬取练习'
# 200
# ISO-8859-1
# utf-8
# utf-8
# 200
# {'user-agent': 'Mozilla/5.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}
# <i class="a-icon a-icon-alert"></i>
#                 <h4>请输入您在下方看到的字符</h4>
#                 <p class="a-last">抱歉，我们只是想确认一下当前访问者并非自动程序。为了达到最佳效果，请确保您浏览器上的 Cookie 已启用。</p>
#                 </div>
#             </div>
#
#             <div class="a-section">
#
#                 <div class="a-box a-color-offset-background">
#                     <div class="a-box-inner a-padding-extra-large">
#
#                         <form method="get" action="/errors/validateCaptcha" name="">
# ...

# %%
#百度360搜索关键词提交练习，用程序自动向这两个搜索引擎提交关键词并获得搜索结果
#搜索引擎有专门的关键词提交接口
#百度关键词接口http://www.baidu.com/s?wd=keyword
#360的关键词接口hyyp://www.so.com/s?q=keyword
import requests
kv={'wd':'Python'}
r=requests.get('http://www.baidu.com/s',params=kv)
print(r.status_code)
print(r.request.url)
len(r.text)

#跟老师运行的结果又不太一样☹️
# Out:
# 200
# https://wappass.baidu.com/static/captcha/tuxing.html?&logid=7908566261427963342&ak=c27bbc89afca0463650ac9bde68ebe06&backurl=https%3A%2F%2Fwww.baidu.com%2Fs%3Fwd%3DPython&ext=x9G9QDmMXq%2FNo87gjGO0PxMdQnKo4ptwOY%2BDmt4UzVoaaeyhUvJM%2FH2FbXwC2V2ug1T9i%2F9aWxTqDk%2BHyX%2BPszWhxC3k6fSFCGM%2FpRvBusF7ef1pqAF6fRTM8gkSm4noSCAe1EQ3IsG%2BFn2u6CQ8X13Hwt0XElCX3OFO28GnHI8%3D&signature=958585978c76aab48dfcc35d6ec87109&timestamp=1692941421
# 1488

# %%
'''网络图片的爬取和存储练习
网络图片链接的格式http://www.example.com/picture.jpg
国家地理网站http://www.nationalgeographic.com.cn/
选择一个图片web页面http://www.nationalgeographic.com.cn/photography/photo_of_the_day/3921.html
右键选中的图片，点击属性，就能得到图片地址，例如，以jpg结尾的就说明是个图片链接，且是个文件
图片是个二进制格式，如何把它保存为一个文件呢'''

#下面代码临时存起来，可执行，但不是很严谨，忘记时看
'''
import requests
path='0825practice.jpg'
url='http://img0.dili360.com/pic/2022/11/21/637af02e6b2bc7o83550809_t.jpg'
r=requests.get(url)
print(r.status_code)
with open(path,'wb') as f:
    f.write(r.content)#r.content表示返回内容的二进制形式
    f.close()
#好神奇啊，上面这段代码，直接把网站上的图片高清爬取下来了。我搞清楚了，这台电脑，如果不写路径，文件会直接创建
#或存储到MacBookPro/用户/linzhiying/这个路径下，而这个路径就是这台电脑的主路径了

import requests
path='pythonpractice/0825practice.jpg'
url='http://img0.dili360.com/pic/2022/11/21/637af02e6b2bc7o83550809_t.jpg'
r=requests.get(url)
print(r.status_code)
with open(path,'wb') as f:
    f.write(r.content)
    f.close()
#这段代码，是把文件存储路径改为主路径（MacBookPro/用户/linzhiying/）下pythonpractice这个文件夹内
'''


'''图片爬取全代码，这是更为标准严谨的写法！
获取图片时用图片原有的名字存储在本地，只需要把URL中最后那段图片文件的名字截取下来，作为
本地目录的名字就可以了'''
import requests,os
url='http://v-wb.youku.com/v_show/id_XNTE5ODk0ODQ4MA==.html'
root='pythonpractice/'#定义一个根目录
path=root+url.split('/')[-1]#url.split('/')[-1]指URL反斜杠分隔的最后一段
try:
    if not os.path.exists(root):#判断当前根目录存不存在，不存在就建立一个
        os.mkdir(root)
    if not os.path.exists(path):#判断这个文件是否粗存在
        r=requests.get(url)
        with open(path,'wb') as f:
          f.write(r.content)
          f.close()
          print("文件保存成功")
    else:
         print("文件已存在")
except:
    print("文件爬取失败")
#从功能意义上讲，写出一个代码并没有什么神奇的。而在工程要求上，写代码的可靠性和稳定性（简单说就是你的代码
#怎么执行都不会错），这是非常非常重要的。所以即使是在写这样一个简单代码的时候，都要去考虑它可能出现的问题
#并能够对问题作相关的处理。网上的一个视频，网上的一个flash，网上的一个动画等等，都可以用类似代码获取下来
# Out:
# '网络图片的爬取和存储练习\n网络图片链接的格式http://www.example.com/picture.jpg\n国家地理网站http://www.nationalgeographic.com.cn/\n选择一个图片web页面http://www.nationalgeographic.com.cn/photography/photo_of_the_day/3921.html\n右键选中的图片，点击属性，就能得到图片地址，例如，以jpg结尾的就说明是个图片链接，且是个文件\n图片是个二进制格式，如何把它保存为一个文件呢'
# "\nimport requests\npath='0825practice.jpg'\nurl='http://img0.dili360.com/pic/2022/11/21/637af02e6b2bc7o83550809_t.jpg'\nr=requests.get(url)\nprint(r.status_code)\nwith open(path,'wb') as f:\n    f.write(r.content)#r.content表示返回内容的二进制形式\n    f.close()\n#好神奇啊，上面这段代码，直接把网站上的图片高清爬取下来了。我搞清楚了，这台电脑，如果不写路径，文件会直接创建\n#或存储到MacBookPro/用户/linzhiying/这个路径下，而这个路径就是这台电脑的主路径了\n\nimport requests\npath='pythonpractice/0825practice.jpg'\nurl='http://img0.dili360.com/pic/2022/11/21/637af02e6b2bc7o83550809_t.jpg'\nr=requests.get(url)\nprint(r.status_code)\nwith open(path,'wb') as f:\n    f.write(r.content)\n    f.close()\n#这段代码，是把文件存储路径改为主路径（MacBookPro/用户/linzhiying/）下pythonpractice这个文件夹内\n"
# ...

# %%
#用来测试找的图片地址是不是我想要的
import requests,os
#url='https://wx4.sinaimg.cn/large/005X7TAFly1fzkzhzisv5j305i03nglj.jpg'
url='https://qiniu.cuiqingcai.com/6s9pe.png'
root='picturepractice/'#定义一个根目录
path=root+url.split('/')[-1]#url.split('/')[-1]指URL反斜杠分隔的最后一段
try:
    if not os.path.exists(root):#判断当前根目录存不存在，不存在就建立一个
        os.mkdir(root)
    if not os.path.exists(path):#判断这个文件是否粗存在
        r=requests.get(url)
        with open(path,'wb') as f:
          f.write(r.content)
          f.close()
          print("文件保存成功")
    else:
         print("文件已存在")
except:
    print("文件爬取失败")
# Out:
# 文件爬取失败

# %%
'''IP地址归属地的自动查询练习'''
#有一个IP138的网站提供了输入IP地址查归属地这样的功能

import requests
url="http://m.ip138.com/ip.asp?ip="
r=requests.get(url+'202.204.80.112')
print(r.status_code,88)
print(r.text)
#有时候在网站上看到的人机交互式，比如说图形的，文本框的，需要点击按钮的，这种方式在正式
#地向后台服务器提交的时候，其实都是以链接的形式来提交的。只要你能够通过浏览器的解析知道
#向后台提交链接的形式，那你就可以用python代码模拟，向服务器去做正式的提交，而不需要人
#来做这样的事。当你想要向网站自动提交的时候，建议大家去挖掘一下，这个网站后台的API是什么
#不成功，下回再研究吧
